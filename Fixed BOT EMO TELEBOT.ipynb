# %%
import telebot
from telebot import types
bot = telebot.TeleBot('Our token')
@bot.message_handler(commands=['start'])

def start(message):
  markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
  btn1 = types.KeyboardButton("Привет!")
  markup.add(btn1)
  bot.send_message(message.from_user.id, "Привет!", reply_markup=markup)

@bot.message_handler(content_types=['text'])
def get_text_messages(message):
    if message.text == 'Привет!':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('Знаю')
        btn2 = types.KeyboardButton('Не знаю')
        btn3 = types.KeyboardButton('Знаю, но хочу узнать больше')
        markup.add(btn1, btn2, btn3)
        bot.send_message(message.from_user.id, 'Вы уже знаете, что такое эмоциональный интеллект?', reply_markup=markup)


    elif message.text == 'Знаю':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Самопознание')
        btn2 = types.InlineKeyboardButton('Саморегуляция')
        btn3 = types.InlineKeyboardButton('Эмпатия')
        btn4 = types.InlineKeyboardButton('Мотивация')
        btn5 = types.InlineKeyboardButton('Социальные навыки')
        btn6 = types.InlineKeyboardButton('Стрессоустойчивость')
        btn7 = types.InlineKeyboardButton('Другие материалы')
        markup.add(btn1, btn2, btn3, btn4, btn5, btn6, btn7)
        bot.send_message(message.from_user.id, 'О чем хочешь узнать дальше?', reply_markup=markup)


    elif message.text == 'Не знаю':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Самопознание')
        btn2 = types.InlineKeyboardButton('Саморегуляция')
        btn3 = types.InlineKeyboardButton('Эмпатия')
        btn4 = types.InlineKeyboardButton('Мотивация')
        btn5 = types.InlineKeyboardButton('Социальные навыки')
        btn6 = types.InlineKeyboardButton('Стрессоустойчивость')
        btn7 = types.InlineKeyboardButton('Другие материалы')
        markup.add(btn1, btn2, btn3, btn4, btn5, btn6, btn7)
        bot.send_message(message.from_user.id, '''Ну что, подписчики, приветствуем вас! Наш первый пост будет введением в тему эмоционального интеллекта. Что вам нужно знать в первую очередь? Простыми словами, эмоциональный интеллект – это способность человека распознавать свои эмоции и эмоции других людей, контролировать чувства и перенаправлять их на деятельность. Вспомните, что вы делаете после того, как получаете плохую оценку? Если вы можете перераспределить своё огорчение и злость на достижение большей продуктивности, чтобы в следующий раз оценка была хорошей, а не лелеять обиду на себя или преподавателя, поздравляем – это следствие высокого эмоционального интеллекта.
        ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Явление эмоционального интеллекта долгое время не получало должного внимания от научного сообщества. Первопроходцами в этой сфере стали Питер Саловей и Джон Майер, которые в 1989 году опубликовали на эту тему статью в журнале. Для сравнения: первые труды по теме IQ были выпущены ещё в 1912. После статьи Питера Саловея и Джона Майера интерес к исследованию эмоционального интеллекта возрос, и уже в 1995 году Дэниел Гоулман опубликовал книгу “Эмоциональный интеллект. Почему он может значить больше, чем IQ?”. Такой громкий заголовок не мог не привлечь внимания общественности, вызывая скепсис среди бизнесменов и корпораций. Но в наше время заявления об эмоциональном интеллекте уже не кажутся такими сомнительными, поскольку теперь их подкрепляют различные исследования.

        Что же ещё нам нужно знать для понимания темы? Эмоции – это негативная или позитивная реакция на происходящие внешние события или возможность того, что они произойдут. Увидели, как по улице идёт тощий грязный и замёрзший котёнок? Загрустили и расстроились, как мир несправедлив, то есть среагировали на внешние обстоятельства. Накрутили себя, что долгожданный отдых на природе с друзьями может отмениться из-за плохой погоды? Даже несмотря на то, что событие ещё не произошло, вы уже чувствуете сплошной негатив. Также эмоции очень легко перепутать с другим понятием из этой темы – настроением. В чём же разница? Эмоции, в отличие от настроения, зачастую более интенсивны, но кратковременны. Однако не стоит из-за этого недооценивать их влияние на жизнь человека, поскольку эмоции потенциально способны трансформировать личную и социальную сферу.
        ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''

        ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''В случаях, связанных с личными переживаниями и социальными взаимодействиями, человеку как раз помогает эмоциональный интеллект. Человек с высоким ЭИ может лучше воспринимать и распознавать эмоции, понимать их значение и управлять ими, а решение эмоциональных проблем требует от такого человека меньших умственных усилий. Такой человек лучше выражает эмоции вербально и невербально и обладает более высокими социальными навыками. Он склонен быть более открытым и приятным в общении, чем другие, а также такой человек с меньшей вероятностью будет вести себя проблемно и станет избегать саморазрушительного поведения, такого как курение или употребление алкогольных веществ. Человек с высоким ЭИ легче определяет и описывает мотивационные цели и задачи.

        Если вы хотите, чтобы весь предыдущий абзац был описанием вас и вашей жизни, то мы предлагаем вам читать наш блог и дальше, чтобы развивать свой эмоциональный интеллект и становиться лучше вместе с нами!
        ''', reply_markup=markup)
        bot.send_message(message.from_user.id, 'О чем хочешь узнать дальше?', reply_markup=markup)

    elif message.text == 'Знаю, но хочу узнать больше':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Самопознание')
        btn2 = types.InlineKeyboardButton('Саморегуляция')
        btn3 = types.InlineKeyboardButton('Эмпатия')
        btn4 = types.InlineKeyboardButton('Мотивация')
        btn5 = types.InlineKeyboardButton('Социальные навыки')
        btn6 = types.InlineKeyboardButton('Стрессоустойчивость')
        btn7 = types.InlineKeyboardButton('Другие материалы')
        markup.add(btn1, btn2, btn3, btn4, btn5, btn6, btn7)
        bot.send_message(message.from_user.id, '''Явление эмоционального интеллекта долгое время не получало должного внимания от научного сообщества. Первопроходцами в этой сфере стали Питер Саловей и Джон Майер, которые в 1989 году опубликовали на эту тему статью в журнале. Для сравнения: первые труды по теме IQ были выпущены ещё в 1912. После статьи Питера Саловея и Джона Майера интерес к исследованию эмоционального интеллекта возрос, и уже в 1995 году Дэниел Гоулман опубликовал книгу “Эмоциональный интеллект. Почему он может значить больше, чем IQ?”. Такой громкий заголовок не мог не привлечь внимания общественности, вызывая скепсис среди бизнесменов и корпораций. Но в наше время заявления об эмоциональном интеллекте уже не кажутся такими сомнительными, поскольку теперь их подкрепляют различные исследования.

        Что же ещё нам нужно знать для понимания темы? Эмоции – это негативная или позитивная реакция на происходящие внешние события или возможность того, что они произойдут. Увидели, как по улице идёт тощий грязный и замёрзший котёнок? Загрустили и расстроились, как мир несправедлив, то есть среагировали на внешние обстоятельства. Накрутили себя, что долгожданный отдых на природе с друзьями может отмениться из-за плохой погоды? Даже несмотря на то, что событие ещё не произошло, вы уже чувствуете сплошной негатив. Также эмоции очень легко перепутать с другим понятием из этой темы – настроением. В чём же разница? Эмоции, в отличие от настроения, зачастую более интенсивны, но кратковременны. Однако не стоит из-за этого недооценивать их влияние на жизнь человека, поскольку эмоции потенциально способны трансформировать личную и социальную сферу.
        ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Теперь, когда мы знаем историю исследования и основные понятия этой темы, давайте подробнее рассмотрим саму структуру эмоционального интеллекта. Впервые её описали уже известные нам Майер и Саловей. Они разделили эмоциональный интеллект на четыре составляющих: восприятие эмоций, понимание эмоций, управление эмоциями и их использование для облегчения мышления.

        Если говорить о восприятии эмоций, то это способность, позволяющая людям улавливать состояния окружающих, распознавать невербальные сигналы, такие как мимика, жесты и интонации, и проявлять эмпатию, то есть умение сопереживать людям, чувствовать их настроение и находиться с ними “на одной волне”. Представим, что вы договорились о встрече с близким другом. Придя, вы видите, что ваш друг подавлен: голос дрожит, нет улыбки на лице, сидит он скованно и зажато. Так он подаёт невербальные сигналы о своём состоянии. Вероятно, в его жизни произошло какое-то событие, которое заставило его грустить. Если вы смогли уловить это, значит, вы восприняли его эмоции. После того, как вы это сделали, вы уже не можете находиться в приподнятом расположении духа – вы тоже расстраиваетесь и грустите, чувствуете то же, что и ваш друг. Это значит, что вы проявили эмпатию.

', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Исследователи, изучающие тему эмоций, попытались структурировать их и разделить на несколько категорий, чтобы внести ясность. По итогу единой принятой классификации нет до сих пор, но большинство ученых соглашаются, что есть пять основных эмоций, которые и были представлены в мультфильме “Головоломка”: радость, печаль, гнев, страх и отвращение. Мы, в свою очередь, предлагаем вам более подробную классификацию, описывающую восемь базовых эмоций и определяющую степень их интенсивности. Её вы можете пользоваться для того, чтобы лучше понять, что именно вы испытываете, с какими ещё эмоциями ваше состояние может граничить и насколько сильны ваши переживания.
Эту модель Роберт Плутчик предложил в 1980 году, разделив эмоции на полярные друг другу по парам: радость против грусти, злость против страха, восхищение против отвращения и удивление против ожидания. Также он использовал идею цветового круга, чтобы продемонстрировать, что эмоции, как и цвета, могут смешиваться, образовывая новые. Данная модель полноценно, на наш взгляд, описывает спектр эмоций и идея цветовой символики отлично передает их суть.
''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''И последний наш совет на сегодня: если вы хотите углубиться в самопознание и отслеживать свой эмоциональный фон, то в этом вам очень помогут приложения, в которых вы сможете оставлять заметки о том, что чувствуете. Лично мы рекомендуем следующие: Daylio, DailyBean, Moodnotes, EMMO.
Надеемся, что данный пост был интересен и полезен для вас. А также поздравляем – мы приблизились ещё на шаг к тому, чтобы развить свой эмоциональный интеллект, лучше понимать себя и других.
''', reply_markup=markup)

    elif message.text == 'Посмотреть интерактивную модель':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по самопознанию')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)
        bot.send_message(message.from_user.id, 'Посмотреть интерактивную модель можно по этой' + ' [ссылке](https://www.6seconds.org/2022/03/13/plutchik-wheel-emotions/)', reply_markup=markup, parse_mode='Markdown')



    elif message.text == 'Получить дополнительные материалы по самопознанию':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Посмотреть интерактивную модель')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)
        bot.send_message(message.from_user.id,'Статьи, в которых вы можете узнать больше о самопознании:\n 1. Agnoli S, Mancini G, Andrei F and Trombini E (2019) The Relationship Between Trait Emotional Intelligence, Cognition, and Emotional Awareness: An Interpretative Model. Front. Psychol. 10:1711.\n 2.Peña-Sarrionandia A, Mikolajczak M and Gross JJ (2015) Integrating emotion regulation and emotional intelligence traditions: a meta-analysis. Front. Psychol. 6:160.\n 3.Russell, J. A., & Barrett, L. F. (1999). Core affect, prototypical emotional episodes, and other things called emotion: Dissecting the elephant.Journal of Personality and Social Psychology, 76(5), 805–819.\n 4. Wang D, Schneider S, Schwartz JE and Stone AA (2020) Heightened Stress in Employed Individuals Is Linked to Altered Variability and Inertia in Emotions. Front. Psychol. 11:1152. \n 5.Summarizing Emotions from Text Using Plutchik’s Wheel of Emotions. Manshad Abbasi Mohsin, Anatoly Beltiukov © 2019, the Authors. Published by Atlantis Press.', reply_markup=markup, parse_mode='Markdown')


    elif message.text == 'Узнать о другом':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Самопознание')
        btn2 = types.InlineKeyboardButton('Саморегуляция')
        btn3 = types.InlineKeyboardButton('Эмпатия')
        btn4 = types.InlineKeyboardButton('Мотивация')
        btn5 = types.InlineKeyboardButton('Социальные навыки')
        btn6 = types.InlineKeyboardButton('Стрессоустойчивость')
        btn7 = types.InlineKeyboardButton('Другие материалы')
        markup.add(btn1, btn2, btn3, btn4, btn5, btn6, btn7)
        bot.send_message(message.from_user.id, 'О чем хочешь узнать?', reply_markup=markup)

    elif message.text == 'Саморегуляция':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по саморегуляции')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn
''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Однако, нужно понимать,что никакое исследование не идеально, к большому сожалению. Во-первых, средний возраст участников довольно мал, поэтому мы не можем сказать, что результаты распространяются на людей старшего или младшего возраста. Во-вторых, исследование проводилось в Нидерландах и основывалось на других скандинавских исследованиях, а значит, что для России могут быть другие результаты. Подводя итоги, сегодня мы обсудили одну из самых важных частей ЭИ – эмпатию. Надеемся, что вы узнали или отметили для себя что-то новое, что поможет вам в развитии себя и своей жизни. Проходите тест на эмпатию и делитесь результатами в комментариях (если хотите, конечно).
        ''', reply_markup=markup)



    elif message.text == 'Пройти тест по эмпатии':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по эмпатии')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)
        bot.send_message(message.from_user.id, 'Пройти тест “Многофакторный опросник эмпатии” можно по этой ' + ' [ссылке](https://psytests.org/eq/iri.html)', reply_markup=markup, parse_mode='Markdown')


    elif message.text == 'Получить дополнительные материалы по эмпатии':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тест по эмпатии')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)
        bot.send_message(message.from_user.id, 'Статьи, в которых вы можете узнать больше об эмпатии:\n 1. Cuff, B. M. P., Brown, S. J., Taylor, L., & Howat, D. J. (2016). Empathy: A Review of the Concept. Emotion Review, 8(2), 144–153.\n 2. Telle, N.-T., & Pfister, H.-R. (2015). Positive Empathy and Prosocial Behavior: A Neglected Link. Emotion Review, 8(2), 154–163\n 3. Kuypers KPC (2017) Emotional Empathic Responses to Dynamic Negative Affective Stimuli Is Gender-Dependent. Front. Psychol. 8:1491.', reply_markup=markup, parse_mode='Markdown')

    elif message.text == 'Другие материалы':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('В чем польза эмоционального интеллекта?')
        btn2 = types.KeyboardButton('Как развить мотивацию')
        btn3 = types.KeyboardButton('Связь эмоционального интеллекта и ментального здоровья')
        markup.add(btn1, btn2, btn3)
        bot.send_message(message.from_user.id, 'О чем именно хочешь узнать?', reply_markup=markup)

    elif message.text == 'В чем польза эмоционального интеллекта?':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('Пройти тест на эмоциональный интеллект')
        btn2 = types.KeyboardButton('Получить дополнительные материалы по пользе эмоционального интеллекта')
        btn3 = types.KeyboardButton('Узнать о другом')
        markup.add(btn1, btn2, btn3)
        bot.send_message(message.from_user.id, '''Конечно, когда мы говорим о развитии эмоционального интеллекта, мы подразумеваем его прокачку в целом, а не по частям. Но, тем не менее, согласно исследованиям, есть некоторая корреляция между отдельными аспектами ЭИ и конкретными качествами и паттернами поведения личности.''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''В первую очередь хочется упомянуть качество, которое, по мнению многих, больше всего связано с понятием “быть успешным” – лидерство. Если вы внимательно читали предыдущие посты, то для вас не составит труда предположить, как именно высокий показатель ЭИ влияет на лидерские качества и лидерскую позицию человека в группе непосредственно. В исследовании об улучшении эмоционального интеллекта с помощью приложения Dharma Life Program в первую очередь пишут, что данная программа была создана, чтобы помочь людям развить их профессиональные компетенции с помощью тренировки ЭИ. В первую очередь это исследование ссылается на результаты исследований предшественников, которые продемонстрировали, что так называемые “большие лидеры”, то есть лидеры больших компаний в большинстве своём имели высокий показатель ЭИ, в то время как средние и маленькие лидеры имели меньше подобных компетенций. Более того, люди с высоким ЭИ были больше удовлетворены своей работой, проявляли энтузиазм, были сильнее преданы делу и компании.
', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Мы в очередной раз убедились, что ЭИ важен для социальных взаимодействий и может принести вам успех в не только в личной, но и в рабочей сфере. Далее мы поняли, что ЭИ влияет на лидерские качества. Затем обнаружили, что не обязательно развивать ЭИ в целом – можно прокачивать компоненты по отдельности. И затем выявили, какие из компонентов потенциально стоит развивать, чтобы улучшить своё физическое и ментальное здоровье.''', reply_markup=markup)

    elif message.text == 'Пройти тест на эмоциональный интеллект':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по пользе эмоционального интеллекта')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)
        bot.send_message(message.from_user.id, 'Пройти детальный тест на эмоциональный интеллект по этой ' + ' [ссылке](https://www.idrlabs.com/ru/global-eq/test.php)', reply_markup=markup, parse_mode='Markdown')

    elif message.text == 'Получить дополнительные материалы по пользе эмоционального интеллекта':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тест на эмоциональный интеллект')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)
        bot.send_message(
            message.from_user.id,
            'Статьи, в которых вы можете узнать больше о пользе эмоционального интеллекта :\n1. Poonamallee L, Harrington AM, Nagpal M and Musial A (2018) Improving Emotional Intelligence through Personality Development: The Effect of the Smart Phone Application based Dharma Life Program on Emotional Intelligence. Front. Psychol. 9:169. doi: 10.3389/fpsyg.2018.00169\n2. Fernandez-Abascal EG and Martin-Diaz MD (2015) Dimensions of emotional intelligence related to physical and mental health and to health behaviors. Front. Psychol. 6:317. doi: 10.3389/fpsyg.2015.00317',
            reply_markup=markup,
            parse_mode='Markdown'
        )

    elif message.text == 'Как развить мотивацию':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('Пройти тест по мотивации')
        btn2 = types.KeyboardButton('Получить дополнительные материалы по мотивации')
        btn3 = types.KeyboardButton('Узнать о другом')
        markup.add(btn1, btn2, btn3)
        bot.send_message(message.from_user.id, '''Жить без мотивации к чему-либо довольно сложно. Многие ваши действия доведены до автоматизма, и вы уже не можете вспомнить, что заставляло вас совершать те или иные поступки изо дня в день раньше: например петь, рисовать или готовить. В этом случае важно остановиться и хорошенько подумать: что и как может вас замотивировать? Что пробудит в вас желание стараться и прикладывать усилия? Именно на эти вопросы мы постараемся ответить в этом посте.
(Важно отметить, что в данном посте не будет конкретных советов. Это собрание исследований, на основе которых можно сделать практические выводы.)''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Исследователи выделили два типа целей, связанных с мотивацией: цели и мотивации приближения/избегания и цели и мотивации достижения/поддержания. Считается, что различие в типах мотивации зависит от индивидуальных психологических составляющих человека. Две системы ответственные за цели и мотивацию: система поведенческой активации (BAS) и система поведенческого торможения (BIS). BAS активируется, когда за действием следует какая-либо награда. BIS работает, когда за действием, наоборот следует наказание.
Вернемся непосредственно к типам целей и мотивации.
Цели приближения/избегания. Мотивация приблизить, заполучить желаемый результат определяется целями приближения, в то время как мотивация оградиться от чего-то означает, что человек преследует цели избегания. Возьмем к примеру занятие спортом. Человек, стремящийся к здоровому образу жизни или спортивному телу, будет мотивирован ходить в зал или выполнять упражнения дома, то есть действует благодаря цели приближения. А человек, который не хочет располнеть или иметь одышку действует в связи с целью избегания. Однако, стоит отметить, что цели избегания не такие плодотворные, как цели приближения, так как они определяются не так четко и не способствуют развитию.
Цели достижения и поддержания схожи с целями приближения. Когда человек осознает, что его физическая подготовка не соответствует желаемому, он прикладывает усилия, чтобы ее достичь. Другой вид цели - поддерживать текущую форму.''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''По-другому мотивацию можно разделить на внутреннюю и внешнюю. Внутренняя мотивация предполагает, что человек делает именно то, что приносит ему искреннее удовольствие (например, когда выбираешь разгрузиться просмотром нового сериала “Уэнсдей”, а не готовиться к занятию). Внешние причины объясняются желанием получения награды или избежания наказания (получаешь хорошие оценки, чтобы мама не ругалась). Также есть идентифицированные причины, которые не очень приятные, но все равно важны для человека (например, решиться пойти к психологу бывает очень тревожно, но стремление улучшить ментальное состояние важнее).
Многие исследователи приходят к выводу, что внутренняя мотивация работает лучше и дольше, поэтому можно поискать удовольствие или интерес даже в скучных делах. [1]''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''С чем еще связана мотивация? Исследования показали, что фиксированное мышление ограничивает стремления и означает среднюю/низкую мотивацию. Представим, что ученик считает себя гуманитарием, и поэтому не берется разбираться в физике. По его мнению он не понимает физику, потому что не обладает сверхспособностями - это пример фиксированного мышления. Более гибкое мышление позволяет смотреть на препятствия, как на возможность роста и развития новых навыков, что повышает внутреннюю мотивацию.
Что же можно сделать для развития мотивации? Эффективными оказались методы самоубеждения. Их суть состоит в том, что для принятия решения или действия нужно найти внутренние причины. Еще важно сопоставлять получаемую информацию с ее практическим применением, таким образом повысится мотивация учить что-то новое. [2]
В другом исследовании было сделано интересное наблюдение о том, как работает внутренняя мотивация. Во-первых, при условиях некоторого ограничения человека в его деятельности (например, оценки, материальные вознаграждения и дедлайны) воспринимаются этим человеком как контролирующие факторы и подрывают его внутреннюю мотивацию. И наоборот, предоставление выбора и признание чувств поддерживают автономию и усиливают внутреннюю мотивацию. В общем, когда человека контролируют, внутренняя мотивация снижается, а когда ему дают проявить самостоятельность и взять на себя ответственность за свои действия – повышается.
(Однако, этот эксперимент проводился с матерями и их детьми 5-7 лет, где выявить пытались как раз-таки мотивацию ребёнка. Возможно, что этот эксперимент не даст тех же результатов для других возрастов или для людей, находящихся в других отношениях помимо “мать и  ребёнок”.)''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Также для того, чтобы быть мотивирующей, деятельность должна стоять на ступень выше квалификации человека. Для этой деятельности человек должен развивать новые навыки, цель не должна быть слишком легкой и требовать только имеющиеся у человека качества. Попытка бросить себе вызов и научиться тому, что ещё не умеешь, является хорошей внутренней мотивацией. Тем не менее, цель не должна быть слишком сложной, чтобы не утратить интерес к ней. [3]
Таким образом, по итогам этих исследований вы можете сделать для себя определённые выводы. Во-первых, узнать подробнее о механизмах своей мотивации, пройдя тест. Во-вторых, обращать внимание на то, как выглядят ваши цели: к какому типу они относятся, не слишком ли они сложные или легкие. Ну и в-третьих, задуматься о собственной мотивации и поработать с возможными ограничениями, угнетающими вашу мотивацию и описанные выше.''', reply_markup=markup)

    elif message.text == 'Пройти тест по мотивации':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по мотивации')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)
        bot.send_message(message.from_user.id, 'Пройти тест мотивации достижения, ТМД по ' + ' [ссылке](https://psytests.org/emotional/rses.htmlp)', reply_markup=markup, parse_mode='Markdown')

    elif message.text == 'Получить дополнительные материалы по мотивации':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тест по мотивации')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)
        bot.send_message(
            message.from_user.id,
            'Статьи, в которых вы можете узнать больше о мотивации :\n1. Lappi, S. K., & Wilkowski, B. M. (2020). The generalized approach, attainMent, maintenance, and avoidance (GAMMA) motivation scale: development, validation, and theoretical contribution. Motivation and Emotion.\n2. Tóth-Király, I., Morin, A.J.S., Litalien, D. et al. Self-determined profiles of academic motivation. Motiv Emot 46, 152–170 (2022)\n3. Scott Rigby, C., Deci, E.L., Patrick, B.C. et al. Beyond the intrinsic-extrinsic dichotomy: Self-determination in motivation and learning. Motiv Emot 16, 165–185 (1992).',
            reply_markup=markup,
            parse_mode='Markdown'
        )

    elif message.text == 'Связь эмоционального интеллекта и ментального здоровья':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.KeyboardButton('Пройти тесты')
        btn2 = types.KeyboardButton('Получить дополнительные материалы по связи эмоционального интеллекта и ментального здоровья')
        btn3 = types.KeyboardButton('Узнать о другом')
        markup.add(btn1, btn2, btn3)
        bot.send_message(message.from_user.id, '''Первое исследование фокусируется на проблеме селфхарма (aka самоповреждения).

Целью исследования было выяснить, связан ли уровень эмоционального интеллекта с риском возникновения желания нанести себе повреждения среди подростков. 136 человек заполнили анкеты, оценивающие определенные психологические аспекты (ЭИ, депрессивные и тревожные симптомы, самооценку, агрессию и импульсивность).
В ходе исследования было выявлено, что низкий уровень эмоционального интеллекта сопряжен с высоким уровнем депрессивного состояния и низкой самооценкой. А тревожность и уровень самооценки являются медиаторами между ЭИ и селфхармом.
Однако у исследования не было достаточно времени, чтобы достоверно проверить все причинно-следственные связи. Также довольно небольшое количество участников и их возрастная категория (только подростки около четырнадцати лет) не позволяют применить результаты на большую популяцию.
Целью следующего исследования было изучить связь между стратегиями регуляции эмоций, проблемами со сном и симптомами депрессии. Как мы помним из поста о саморегуляции, стратегии бывают адаптивными (универсальными, применимыми практически к любой ситуации), и неадаптивными (помогающими не всем и не всегда, а иногда даже вредными для человека).''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Выборка включала 602 стационарных пациента, из которых 421 (69,9%) были женщинами. Средний возраст выборки составил 15,16 года. Стационарным пациентам был поставлен диагноз “депрессивное расстройство” или “расстройство депрессивного поведения”, что было основным диагнозом для 542 (90%) участников. Все участники заполнили анкеты и получили поддержку психолога, чтобы была возможность задавать респондентам вопросы в случае необходимости.

По результатам широкое использование неадаптивных стратегий и малое применение адаптивных часто было сопряжено с проблемами со сном и депрессивными симптомами. Наличие проблем со сном и их интенсивность положительно коррелировали с симптомами депрессии и неадаптивными стратегиями, и отрицательно – с адаптивными. Кроме того, депрессивные симптомы были связаны с увеличением использования неадаптивных стратегий и с уменьшением использования адаптивных стратегий. Также на эту связь значительно влиял пол участников, в отличие от их возраста. Девочки в два-три раза чаще страдают от депрессивных симптомов, проблем со сном и нарушения эмоциональной регуляции, чем мальчики. Таким образом, чем больше неадаптивных стратегий и чем меньше адаптивных вы используете, тем выше риск наличия у вас депрессивных симптомов.
Однако, как и любое другое исследование, это имеет свои недостатки. Во-первых, были использованы результаты самоотчетов участников, что могло понизить объективность ответов. Во-вторых, выборка была клинической, что ограничивает возможность обобщения результатов на популяционные выборки. [2]
Таким образом, из этих исследований мы узнали, как ЭИ и некоторые его компоненты коррелируют с ментальным здоровьем.''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Возможно, это натолкнуло вас на некоторые мысли, и вы пересмотрели стратегии своего поведения. Тем не менее, надеемся, что в этих исследованиях вы не узнали себя, и что вы можете похвастаться отличным психическим здоровьем. Если же это не так, то помните: ни один тест, ни один пост в интернете не может поставить вам диагноз и решить все ваши проблемы – сделать это может только специалист. Если вы чувствуете, что что-то в вашей жизни идёт не так, всегда лучше обратиться за помощью к знающему человеку: если проблема действительно существует, он поможет с нею справиться, а если нет – выдохните спокойно.
''', reply_markup=markup)

    elif message.text == 'Пройти тесты':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы о связи эмоционального интеллекта и ментального здоровья')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)
        bot.send_message(message.from_user.id, 'Пройти тест: Шкала самооценки Розенберга (SES) по' + ' [ссылке](https://psytests.org/emotional/rses.html)\n Тест, похожий на опросник импульсивности Айзенка' + '[(IVE)](https://psytests.org/emotional/bis11ru.html)'
        , reply_markup=markup, parse_mode='Markdown')

    elif message.text == 'Получить дополнительные материалы о связи эмоционального интеллекта и ментального здоровья':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тесты')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)
        bot.send_message(
            message.from_user.id,
            'Статьи, в которых вы можете узнать больше о связи эмоционального интеллекта и ментального здоровья :\n1. Halicka-Masłowska J, Szewczuk-Bogusławska M, Rymaszewska J, Adamska A and Misiak B (2021) From Emotional Intelligence to Self-Injuries: A Path Analysis in Adolescents With Conduct Disorder. Front. Psychiatry 11:556278. doi: 10.3389/fpsyt.2020.556278\n2. Kirschbaum-Lesch I, Holtmann M and Legenbauer T (2021) Deficits in Emotion Regulation Partly Mediate the Relation Between Sleep Problems and Depressive Symptoms in Adolescent Inpatients With Depression. Front. Psychiatry 12:622833. doi: 10.3389/fpsyt.2021.622833',
            reply_markup=markup,
            parse_mode='Markdown'
        )

    elif message.text == 'Мотивация':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тест по мотивации')
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по мотивации')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1,btn2,btn3)
        bot.send_message(message.from_user.id, '''Привет! Сегодня мы поговорим про последний аспект представленной нами модели эмоционального интеллекта – мотивацию. Что же это такое и почему она напрямую влияет на эмоциональный интеллект? Мотивация – это внутренний или социальный стимул, побуждающий человека к определённым действиям. Её отсутствие обычно связано с эмоциональной незрелостью, а в ситуациях, когда мотивация есть, но цель человек всё равно не может достичь, обычно прослеживается влияние плохой организации или низкого интеллекта.

    Существует множество теорий, объясняющих мотивацию, но в наше время исследователи сместили свой интерес в сторону социально-когнитивного объяснения феномена. Эта теория подчёркивает, что мотивировать человека можно множеством способов, и что мотивацию не стоит измерять количественно. У одного и того же стимула нет степени или градации, но этот стимул можно сравнить с другим стимулом и сравнить их силу. Современные теории мотивации фокусируются на четырех конструктах: убеждениях, связанных с компетентностью, убеждениях контроля, субъективных ценностях задачи и ориентации на достижение цели, - все эти четыре аспекта влияют на формирование мотивации человека''' , reply_markup=markup, parse_mode='Markdown')
        bot.send_message(message.from_user.id, '''Мотивация для каждого индивидуальна, и то, что может стать стимулом действовать для одного человека, другого не заставит и пальцем пошевелить. Именно поэтому так важно уметь находить собственную мотивацию, понимать свои цели, желания и границы.

    Наглядным примером мотивации и того, что она индивидуальна для каждого, будет мультфильм “Кунг-фу панда”. Нам кажется, что даже те, кто не смотрел его, уже знают сюжет: волей случая панду По, фаната боевых искусств, работающего у отца в лапшичной, выбирают Воином Дракона – тем, кто получит свиток с секретом неукротимой силы, чтобы защищать народ. Но По, кажется, совсем не подходит на эту роль. Его мотивацией было понравиться своему тренеру и своей команде, поэтому он пытался вести себя уверенно и расслабленно, старался на тренировках, но у него ничего не получалось. Мастер Шифу, его тренер, не возлагал на панду никаких надежд, пока однажды не увидел чудеса гимнастики и боевых искусств в исполнении По, пока тот лез за печеньем. Мастер понял, что один из главных стимулов По – это желание утолить голод вкусной едой, поэтому создал для него индивидуальную программу тренировок, где конечной целью выполнения всех упражнений была возможность получить пельмешку. Пока другие из команды тренировались потому, что хотели стать сильнее и побеждать врагов, что и было их мотивацией, По совсем не желал внезапно свалившегося ему на голову груза ответственности, поэтому эта мотивация не была для него актуальной. Но вот ради еды… Здесь мы всецело поддерживаем и ассоциируем себя с этим персонажем''', reply_markup = markup, parse_mode = 'Markdown')
        bot.send_message(message.from_user.id, ''' Мотивацию и настрой также можно спровоцировать, навести человека на определённые мысли и навязать ему желание. Подобные манипуляции могут также повлиять на эмпатическую точность, способность понимать и оценивать эмоции окружающих. То есть если внушить человеку мотивацию, он, вероятно, по-другому будет оценивать обстановку вокруг.

    Так, был проведён эксперимент, чтобы выявить связь между мотивацией и эмпатией при решении конфликтов в романтических отношениях. Ученые, организовавшие этот эксперимент, были заинтересованы в различных формах мотивации: мотивации, служащей отношениям; мотивации, служащей собственным целям; мотивации, служащей партнеру. В таком исследовании поучаствовали 172 пары, длительность отношений которых более 1 года и возраст обоих партнеров не менее 21 года.  В лаборатории партнерам давали список общих конфликтных тем в интимных отношениях, например: финансы, привязанность, разделение домашних обязанностей. Обоих партнеров просили определить три темы, по которым они расходились во мнениях и были наиболее важными для них. Партнерам в каждой паре было сказано, что каждый из них будет самостоятельно готовиться к предстоящему обсуждению темы конфликта под руководством научного сотрудника. Для каждого типа изучаемой мотивации было выбрано равное количество пар, и задавались вопросы, наталкивающие на соответствующий тип.

    В условиях мотивации, служащей отношениям, партнерам задавали вопросы, которые должны были вызвать мотивацию для достижения наилучшего возможного результата в отношениях, например “Как вы могли бы попытаться достичь компромисса?”. В условиях корыстной мотивации вопросы были сосредоточены на собственном благополучии участника, например “Как вы могли бы убедить партнера в своем мнении в следующем разговоре?”. Наконец, в условии мотивации, служащей партнеру вопросы были направлены на повышение мотивации для максимального благополучия своего партнера, например “Как бы вы согласились с мнением вашего партнера в следующем разговоре?”. Также было контрольное условие, в котором партнерам задавали несколько основных, довольно нейтральных вопросов по выбранной ими теме конфликта, например “Как часто вы разговариваете на эту тему? Кто обычно инициирует разговор на эту тему?”.''', reply_markup = markup, parse_mode = 'Markdown')
        bot.send_message(message.from_user.id, ''' Подводя итоги, исследователи пришли к выводу, что более высокая мотивация, служащая отношениям, предсказывала большую степень эмпатии в решении конфликта у женщин. Тем не менее, удивительным выводом было то, что мотивация, служащая в интересах партнера наоборот оказывала негативное влияние на точность эмпатии у мужчин. Возможно, повышенная мотивация служить партнеру могла заставить мужчину обращать внимание на неправильные сигналы, исходящие от его партнерши.  В общем и целом, большая мотивация поддержать и сохранить отношения положительно взаимосвязана с проявляемой к партнеру эмпатией.

    На этом мы закончили рассматривать упрощенную модель эмоционального  интеллекта, которую мы приводили в первом посте, и её компоненты. Теперь, когда мы знаем основы, мы сможем обсуждать эмоциональный интеллект более углублённо. Надеемся, сегодня вам было интересно с нами!''', reply_markup = markup, parse_mode = 'Markdown')



    elif message.text == 'Пройти тест по мотивации':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        bot.send_message(message.from_user.id, 'Пройти тест на природу твоей мотивации можно по' + '[ссылке](https://psytests.org/emvol/mats.html)', reply_markup=markup, parse_mode='Markdown')
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по мотивации')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)

    elif message.text == 'Получить дополнительные материалы по мотивации':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        bot.send_message(message.from_user.id, '''1)Bekerman, & Zembylas, M. (2017). Emotion, Emotional Intelligence and Motivation. Psychologized Language in Education, 67–78
    2) Jenkins, L. N., & Demaray, M. K. (2015). AN INVESTIGATION OF RELATIONS AMONG ACADEMIC ENABLERS AND READING OUTCOMES. Psychology in the Schools, 52(4), 379–389.
    3) Berlamont, L., Hodges, S., Sels, L. et al. Motivation and empathic accuracy during conflict interactions in couples: it’s complicated!. Motiv Emot (2022)''', reply_markup=markup, parse_mode='Markdown')
        btn1 = types.InlineKeyboardButton('Пройти тест по мотивации')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)

    elif message.text == 'Узнать о другом':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Самопознание')
        btn2 = types.InlineKeyboardButton('Саморегуляция')
        btn3 = types.InlineKeyboardButton('Эмпатия')
        btn4 = types.InlineKeyboardButton('Мотивация')
        btn5 = types.InlineKeyboardButton('Социальные навыки')
        btn6 = types.InlineKeyboardButton('Стрессоустойчивость')
        btn7 = types.InlineKeyboardButton('Другие материалы')
        markup.add(btn1, btn2, btn3, btn4, btn5, btn6, btn7)
        bot.send_message(message.from_user.id, 'О чем хочешь узнать?', reply_markup=markup, parse_mode='Markdown')

    elif message.text == 'Социальные навыки':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тест по социальным навыкам')
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по социальным навыкам')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1,btn2,btn3)
        bot.send_message(message.from_user.id, '''Привет! Сегодня мы, наконец-то, перейдём к более практической части нашего блога и начнём разговор о социальных взаимодействиях и о том, как на них может влиять эмоциональный интеллект.

    В первую очередь мы хотим поговорить о взаимосвязи социальных взаимодействий и одного из аспектов ЭИ, а именно саморегуляции. Стратегии саморегуляции играют ключевую роль в социальном взаимодействии, помогают людям адаптироваться и овладеть ситуацией. Тем не менее, ещё не до конца ясно, в какой степени регуляция влияет именно на интерактивные социальные ситуации. Одним из способов изучения их связи было исследование стратегий регуляции эмоций, применяемых к задачам, основанным на теории игр. Она исследует взаимодействие лиц, принимающих решения, их сотрудничество и их конфликты, предлагает модели социального поведения и оценивает влияние социальных факторов на эмоции и решения.  В нескольких исследованиях использовались теоретико-игровые подходы для изучения регуляции эмоций в интерактивном контексте.''', reply_markup=markup, parse_mode='Markdown')
        bot.send_message(message.from_user.id, '''Но не все стратегии саморегуляции [2] могут подойти под конкретную ситуацию. В целом их можно разделить на несколько категорий, представленных в таблице: адаптивные, неадаптивные и внешние.

    Среди них наименьшей эффективностью обладают неадаптивные стратегии. Такие стратегии не универсальны, они могут подойти не всем и не во всех ситуациях. Это может “выстрелить” один раз, но полноценно полагаться на такие стратегии не стоит, поскольку они приводят к саморазрушительному поведению. Используя их для регуляции эмоций, человек чаще всего будет заходить в тупик. Более того, неадаптивные стратегии могут пагубно сказаться и на социальных взаимодействиях, потому что при их использовании эмоции могут потенциально чаще выйти из-под контроля, а также некоторые стратегии, такие как самообесценивание, агрессивные действия и желание сдаться могут оттолкнуть окружающих.

    И наоборот, адаптивные внутренние стратегии более универсальны. В то время как внешние стратегии помогут не только регулировать собственные эмоции, но и наладить контакт с окружающими посредством выражения эмоций, передачи верных сигналов людям.''', reply_markup = markup, parse_mode = 'Markdown')
        bot.send_message(message.from_user.id, '''Также на социальные взаимодействия значительно влияет контекст ситуации [3]. Правильный анализ и понимание контекста способствует более эффективным социальным контактам. Например, вы видите, что человек злится – это понятно по его выражению лица, по резким движениям, напряженной интонации. Всё это - контекст. Далее вы пытаетесь понять причину его злости – было ли это внешнее обстоятельство (длинная очередь, водители на дороге и т.д.) или внутренние переживания, которые известны только этому мужчине. В зависимости от контекста способы вашего взаимодействия могут отличаться: вы можете избежать контакта с этим мужчиной, попытаться его успокоить или наоборот поддержать его эмоции и проникнуться ими.

    В общем и целом, ЭИ, способность понимать сигналы, которые передают люди своими словами, мимикой и жестами и умение правильно их интерпретировать напрямую влияют на освоение социальных навыков. Но для чего же стоит постоянно их развивать? Чем высокий показатель социальных навыков так важен и как он влияет на жизнь?''', reply_markup = markup, parse_mode = 'Markdown')
        bot.send_message(message.from_user.id, '''В выбранном нами исследовании изучается взаимосвязь между социальными навыками и удовлетворенностью жизнью, а также разница этих показателей для мужчин и женщин [4]. Ученые выбрали 459 студентов (234 женщины и 225 мужчин) первого и выпускного курса университета. Участники проходили две анкеты без ограничения по времени: SSI (тест по инвентаризации социальных навыков) и SWLS (шкала удовлетворенности жизнью).

    By the way, мы нашли оба используемых теста, но SSI доступен только на английском :( смело проходите его, если знаете английский язык

    В результате, исследователи обнаружили, что женщины набрали более высокие баллы, чем мужчины, как по социальным навыкам, так и по удовлетворенности жизнью. Таким образом, по сравнению с мужчинами, женщины лучше развивают близкие отношения, рассказывают о себе нынешним друзьям и выражают свои эмоции. Более того, оценки социальных навыков и удовлетворенности жизнью у старшекурсников оказались значительно выше, чем у первокурсников.
    И самое главное, в результате была выявлена положительная корреляция между уровнем социальных навыков и удовлетворенностью жизнью.''', reply_markup = markup, parse_mode = 'Markdown')
        bot.send_message(message.from_user.id, '''Однако если вы первокурсник, или мужчина, или не обладаете хорошими социальными навыками – не спешите расстраиваться. Во-первых, мы предполагаем, что личные качества и культурные особенности, могут иметь большее влияние на объяснение удовлетворенности жизнью, чем пол. Во-вторых, разница для первокурсников и старшекурсников может быть основана на условиях преподавания, а также на количестве выполненных групповых/курсовых работ. В-третьих, положительная корреляция между социальными навыками и удовлетворённостью жизнью была найдена, однако эта корреляция была слабой.''', reply_markup = markup, parse_mode = 'Markdown')

    elif message.text == 'Пройти тест по социальным навыкам':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        bot.send_message(message.from_user.id, 'Пройти тест по социальным навыкам (на английском) можно по ' + '[ссылке](https://www.proprofs.com/quiz-school/story.php?title=social-skills-inventory)' + '\nПройти тест на уровень самоконтроля можно по ' + '[ссылке](https://psytests.org.ru/emvol/bscs.html)', reply_markup=markup, parse_mode='Markdown')
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по социальным навыкам')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)

    elif message.text == 'Получить дополнительные материалы по социальным навыкам':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        bot.send_message(message.from_user.id , """1.Grecucci A, Giorgetta C, Bonini N and Sanfey AG (2013) Living emotions, avoiding emotions: behavioral investigation of the regulation of socially driven emotions. Front. Psychology 3:616.
    2. Sanchis-Sanchis A, Grau MD, Moliner A-R and Morales-Murillo CP (2020) Effects of Age and Gender in Emotion Regulation of Children and Adolescents. Front. Psychol. 11:946.
    3. Baez S, García A and Ibáñez A (2018) How Does Social Context Influence Our Brain and Behavior?. Front. Young Minds. 6:3.
    4. Malinauskas, R., Dumciene, A., & Lapeniene, D. (2014). Social Skills and Life Satisfaction of Lithuanian First- and Senior-Year University Students. Social Behavior and Personality: An International Journal, 42(2), 285–293) """, reply_markup=markup, parse_mode='Markdown')
        btn1 = types.InlineKeyboardButton('Пройти тест по социальным навыкам')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)


    elif message.text == 'Стрессоустойчивость':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тест по стрессоустойчивости')
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по стрессоустойчивости')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1,btn2,btn3)
        bot.send_message(message.from_user.id, '''Стрессоустойчивость – это способность человека успешно адаптироваться к трудностям. После стрессового события в жизни некоторые люди способны восстанавливаться быстрее, чем другие. Именно поэтому саму устойчивость рассматривают как совокупность качеств, черт личности, которые помогают человеку справляться с невзгодами. Вы можете быть немного потеряны: причем же тут эмоциональный интеллект? Дело в том, что подавляющее большинство исследований в этой области показывают, что люди с более высоким ЭИ обладают большей устойчивостью. Создатели концепции (Сэловей, Майер,1999) объясняют это тем, что люди с более высоким уровнем эмоционального интеллекта способны «точно воспринимать и оценивать свои эмоции, знать, как и когда выражать свои чувства и могут эффективно регулировать свое настроение».
            ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Удобнее всего будет рассмотреть это явление и выделить его основные аспекты на примере анализа следующей статьи. Испанские исследователи изучали связь между эмоциональным интеллектом и устойчивостью к стрессу в двух странах: США и Испании. Участниками стали 698 студентов бакалавриата из обеих стран. Они измеряли эмоциональный интеллект по Self-Rated Emotional Intelligence Scale (шкала эмоционального интеллекта), а также оценивали устойчивость по шкале воспринимаемого стресса. По результатам этих исследований был сделан вывод, высокий эмоциональный интеллект положительно влияет на устойчивость человека к стрессу. Студенты, набравшие высокие баллы по ЭИ, также хорошо проявили способность справляться со стрессовыми ситуациями, несмотря на риски и обстоятельства. Также было выявлено, что высокие показатели устойчивости оказывают значительное негативное влияние на воспринимаемый стресс. Этот вывод подтверждает более раннюю гипотезу о том, что люди с высокой устойчивостью склонны более эффективно справляться и восстанавливаться после ежедневного стресса, что отражается на качестве жизни в целом. В контексте проведенного исследования со студентами университета можно говорить о том, что те, кто набрал высокий балл ЭИ и устойчивости, намного быстрее и эффективнее адаптируются к новой учебной среде.
            ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Соответственно, результаты продемонстрировали наличие положительной корреляции между показателями ЭИ, устойчивостью и способностью справляться со стрессом. Было также продемонстрировано, что ЭИ связан с субъективным благополучием, психическим здоровьем, социальной поддержкой; устойчивость связана с удовлетворенностью жизнью и самооценкой; и что стресс связан с низкой самооценкой, пессимизмом и низкими показателями чувства собственной эффективности. Тем не менее, мы не можем полноценно полагаться на результаты данного исследования. Во-первых, выборка исследования слишком узкая, чтобы мы могли распространить результаты на людей другого возраста и другой культуры. Во-вторых, можно только предполагать, что высокий уровень устойчивости напрямую влияет на восприятие стресса. Поскольку исследователи не наблюдали за респондентами, они не могут точно сказать, как те справляются со стрессом. Респонденты могут быть предвзятыми по отношению к себе и обстоятельствам и не давать объективную оценку своим действиям.
            ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''Мы уверены, что каждый из вас хоть раз слышал такие слова как “оптимизм” и “пессимизм”. Но в то же время немногие из вас предполагали, что данные слова каким-то образом связаны с ЭИ. В одном из исследований предположили, что уровень эмоциональной осведомленности и саморегуляции может частично отражать оптимизм или пессимизм отдельного человека. На всякий случай напомним, что оптимизм - это ожидание положительных результатов и событий в будущем, а пессимизм, наоборот, - отрицательных. Исследователи предполагают, что эти показатели влияют на то, как люди справляются со стрессовыми переживаниями и насколько это успешно. Например, оптимистам приписывают большую удовлетворенность жизнью, а также менее сильный уровень воспринимаемого стресса. В исследовании приняли участие 498 участников из одной провинции Испании. Респонденты проходили тест диспозиционного оптимизма, а также уже упомянутые нами шкалу воспринимаемого стресса и шкалу удовлетворенности жизнью. В результате, как и ожидалось учеными, участники пессимисты показывали более сильный воспринимаемый стресс и более низкую удовлетворенность жизнью. Однако женщины показали значительно более высокие показатели внимания, пессимизма и воспринимаемого стресса, чем мужчины. С другой стороны, у мужчин показатели ясности значительно выше, чем у женщин. ремонт и оптимизм. Аналогичные результаты, касающиеся более быстрого восстановления настроения у мужчин, были получены Thayer et al. (2003)
            ''', reply_markup=markup)
        bot.send_message(message.from_user.id, '''И все же, в данном исследовании использовались тесты, в которых участник самостоятельно выносит суждения о своих навыках и состоянии. В таком случае, участвующие могли быть предвзяты или склонны к самоутверждению. Более того, по данному исследованию нельзя сделать точный вывод о причинах таких результатов. Возможно, пессимизм или оптимизм не единственная причина низкой удовлетворенности жизнью или высоким уровнем стресса. Надеемся, что этот пост был полезен для вас, и вы в очередной раз убедились, как важно развивать эмоциональный интеллект, ведь помимо прочего, он влияет и на одну из самых важных способностей – стрессоустойчивость. Как всегда, ждём результаты тестов в комментариях.
            ''', reply_markup=markup)

    elif message.text == 'Пройти тест по стрессоустойчивости':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn2 = types.InlineKeyboardButton('Получить дополнительные материалы по стрессоустойчивости')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn2, btn3)
        bot.send_message(message.from_user.id, 'Пройти тест “Самооценка эмоционального интеллекта” можно по ' + ' [ссылке](https://hr-portal.ru/article/samoocenka-emocionalnogo-intellekta-testl)' + '\nПройти тест “Шкала воспринимаемого стресса-10” можно по ' + '[ссылке](https://www.samopomo.ch/proversja/shkala-vosprinimaemogo-stressa-10-pss)' + '\nПройти тест “Тест диспозиционного оптимизма, LOT-R” можно по' + '[ссылке](https://psytests.org/life/lotr.html)', reply_markup=markup, parse_mode='Markdown')

    elif message.text == 'Получить дополнительные материалы по стрессоустойчивости':
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1 = types.InlineKeyboardButton('Пройти тест по стрессоустойчивости')
        btn3 = types.InlineKeyboardButton('Узнать о другом')
        markup.add(btn1, btn3)
        bot.send_message(message.from_user.id, '''Статьи, в которых вы можете узнать больше об эмпатии:\n 1.Sarrionandia A, Ramos-Díaz E and Fernández-Lasarte O (2018) Resilience as a Mediator of Emotional Intelligence and Perceived Stress: A Cross-Country Study. Front. Psychol. 9:2653.
        \n 2. Natalio Extremera, Auxiliadora Durán, Lourdes Rey (2007) Perceived emotional intelligence and dispositional optimism–pessimism: Analyzing their role in predicting psychological adjustment among adolescents, Personality and Individual Differences, Volume 42, Issue 6, Pages 1069-1079''', reply_markup=markup, parse_mode='Markdown')



bot.polling(none_stop=True, interval=0)
